# %%
from os import listdir
from skimage import io
import cv2


def thresholding(image, value):
    return image > value


def main():
    for filename in listdir("images"):
        file = io.imread(f"images/{filename}", as_gray = True)
        
        # Wykrywanie liczby plansz 
        
        # Wydzielane pojedyncze plansze
        
        # Obracanie zeby bylo pionowo (2 linie pionowo, 2 poziomo)
            # Znajdowanie linii
            # Transformacja Hough (obliczanie kąta)
            # rotacja zdjecia zeby dolna linia byly poziomo
        
        # Wyznaczanie punktow przeciecia planszy
        # Wyznaczanie polozenia obiektu na planszy (ktore z 9 pozycji)
        # (jakos z momentow centralnych)
        
        
        # Dylatowanie czy cos zeby zwiekszyc dokladnosc wczytywania x i o
        
        # Momenty Hu / kolorowanie
        
        # Koniec
        
        io.imshow(file)
        
            


if __name__ == "__main__":
    main()
